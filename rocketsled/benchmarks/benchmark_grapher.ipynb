# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
from rocketsled.benchmarks.benchmarker import visualize, load_csets, plot_random
# plt.rcParams['figure.figsize'] = [12, 10]

# %%
# Set the parameters for how the plot should look
func = 'bran'
optimizer_names = ['gp', 'rf', 'gphyper']
style = 'abs_error'
limit = 50

# %%
# Plot
print("Analyzing collections")
plt = visualize(optimizer_names, func, limit=limit, fontfamily="sans serif", fill=False, style=style, log=True)
print("Plotting random")
plt = plot_random(plt, func, returnval=style, limit=limit)
plt.legend()
print("Showing...")
plt.show()
# Out:
# Analyzing collections
# Plotting random
# Showing...
